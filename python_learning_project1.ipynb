# %%
# My first Python program
name = input("What is your name? ")
print(f"Hello {name}!")
print("I am starting my journey to ₹50+ LPA by 2032!")
# Out:
# What is your name? pranitha
# Hello pranitha!
# I am starting my journey to ₹50+ LPA by 2032!
